# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanhassell/IDS/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem #1

# %% [markdown]
# [Link to Google Sheets](https://docs.google.com/spreadsheets/d/1O59OGO7meLcJ5Mh_ffCHV6Lb0-0JpHIAQhwVpo_X1cU/edit?usp=sharing) (The Sum graph is on this page)

# %% [markdown]
# Here is my chart of the Mean, Max, and Minimum weights.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Based on the results, it seems to me that either Sunflower or Casein are the best, but Casein is a bit better by a small margin. This is due to the higher minimum weight while also having a very similar average, a difference very close to just one pound.

# %% [markdown]
# # Problem #2

# %% [markdown]
# [.csv file link](https://github.com/ryanhassell/IDS/blob/DataSci-Extra-Credit/insuranceratings.csv)

# %% [markdown]
# [Link to Google Sheets](https://docs.google.com/spreadsheets/d/1tbJ8RojL4dd3uMo4mBJpGWBvO1X86tbD10oJ9CF1T8U/edit?usp=sharing) (The Sum graph is on this page)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Based off of these results, I would choose Progressive. It has the middlemost maximum rating, the highest average, and the highest minimum. Progressive also has the greatest review score sum, .8 greater than GEICO.
