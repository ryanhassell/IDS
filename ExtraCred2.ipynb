# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanhassell/IDS/blob/DataSci-Extra-Credit/ExtraCred2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project 2

# %% [markdown]
# The code supplied did not work, and it threw a Syntax error. I fixed this problem by adding a CHECK IN statment into the line of code that delcared the enum value. It functions normally.

# %% [markdown]
# Original Code:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fixed Code:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
